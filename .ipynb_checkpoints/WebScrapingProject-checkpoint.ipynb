# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install bs4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install regex

# %%
pip install pandas
# Out:
# ...
#
# ...

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import re
import pandas as pd

# %%
url = "https://www.carandbike.com/used/cars-for-sale?transmission=Automatic&utm_source=uc&utm_medium=desktop&utm_campaign=hb&utm_content=july-monsoon-madness"
# this will bring the entire HTML code and store it in variable
page = requests.get(url)
print(page)
# Out:
# <Response [200]>

# %%
#page.content # this is the raw code scraped from the website

# %%
soup = BeautifulSoup(page.content, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
carListingWrapper = soup.find(class_="listingCardContainer")
carListingWrapper
# Out:
# <ul class="listingCardContainer grid"><li data-list="new-page"><div><div class="usedCarCard widgets js-widget" data-type="Widget" data-widget="UsedCarCard"><div class="usedCarCard relative imgRound"><div class="ucCardWrap imgRound"><a class="js-tracker relative" href="/used/honda-city-cars-in-thane-198451" rel="" target="_self"><img alt="Used 2019 Honda City, Thane Mumbai" class="ucImage imgRound imgFull" data-nimg="1" decoding="async" height="200" loading="eager" sizes="(max-width: 750px), 50vw" src="/_next/image?url=https%3A%2F%2Fmedia.mahindrafirstchoice.com%2Flive_web_images%2Fusedcarsimg%2Fmfc%2F79%2F611265%2Fcover_image-20240610183105.jpeg&amp;w=3840&amp;q=75" srcset="/_next/image?url=https%3A%2F%2Fmedia.mahindrafirstchoice.com%2Flive_web_images%2Fusedcarsimg%2Fmfc%2F79%2F611265%2Fcover_image-20240610183105.jpeg&amp;w=384&amp;q=75 384w, /_next/image?url=https%3A%2F%2Fmedia.mahindrafirstchoice.com%2Flive_web_images%2Fusedcarsimg%2Fmfc%2F79%2F611265%2Fcover_image-20240610183105.j
# ...

# %%
carTitle =  soup.find_all(class_="ucTitle truncate truncate1")
carMakeYear = []
carModel = []
for i in carTitle:
    title = i.get_text().split(" ")
    model=''
    for j in range(1,len(title)):
        if(j==1):
            model = title[j]
        else:
            model = model + " " + title[j]
    carMakeYear.append(title[0])
    carModel.append(model)
print(carMakeYear)
print(carModel)
# Out:
# ['2019', '2018', '2018', '2021', '2021', '2021', '2017', '2021', '2014', '2018', '2018', '2018', '2018', '2016', '2016', '2015', '2016', '2018', '2017', '2021', '2017', '2017', '2014', '2017', '2015', '2019', '2017', '2017', '2017', '2018']
# ['Honda City', 'Honda Jazz', 'Maruti Suzuki Baleno', 'Maruti Suzuki S-Cross', 'Maruti Suzuki XL6', 'MG Hector', 'Jeep Compass', 'Maruti Suzuki XL6', 'Hyundai Xcent', 'Honda Jazz', 'Honda Jazz', 'Maruti Suzuki Ciaz', 'Honda City ZX', 'Honda Brio', 'BMW X1', 'Mercedes-Benz GL-Class', 'Volkswagen Vento', 'Maruti Suzuki Ciaz', 'Honda City ZX', 'Hyundai Elite i20', 'Hyundai Creta', 'Mahindra XUV500', 'Mercedes-Benz B-Class', 'Hyundai Xcent', 'Volkswagen Vento', 'Hyundai Grand i10', 'Maruti Suzuki Ciaz', 'Honda City', 'Toyota Corolla Altis', 'Hyundai Creta']

# %%
carPrices =  soup.find_all(class_="ucPrice flex gridJcgridAc")
askingPrice=[]
for i in carPrices:
    askingPrice.append(i.get_text())
print(askingPrice)
# Out:
# ['Rs. 8.75 Lakh', 'Rs. 6.75 Lakh', 'Rs. 6.75 Lakh', 'Rs. 9.95 Lakh', 'Rs. 11.85 Lakh', 'Rs. 16.75 Lakh', 'Rs. 11.45 Lakh', 'Rs. 11.55 Lakh', 'Rs. 4.25 Lakh', 'Rs. 6.55 Lakh', 'Rs. 6.75 Lakh', 'Rs. 8.75 Lakh', 'Rs. 9.65 Lakh', 'Rs. 4.85 Lakh', 'Rs. 17.75 Lakh', 'Rs. 35.5 Lakh', 'Rs. 6.35 Lakh', 'Rs. 7.55 Lakh', 'Rs. 8.25 Lakh', 'Rs. 8.75 Lakh', 'Rs. 9.35 Lakh', 'Rs. 11.75 Lakh', 'Rs. 13.65 Lakh', 'Rs. 5.75 Lakh', 'Rs. 6.35 Lakh', 'Rs. 6.45 Lakh', 'Rs. 7 Lakh', 'Rs. 7.95 Lakh', 'Rs. 10.45 Lakh', 'Rs. 11.35 Lakh']

# %%
carImages =  soup.find_all(class_="ucImage imgRound imgFull")
try:
    for i in range(len(carImages)):
        carImages[i] = urljoin(url, carImages[i]['src'])
except:
    pass
print(carImages)
# Out:
# ['https://www.carandbike.com/_next/image?url=https%3A%2F%2Fmedia.mahindrafirstchoice.com%2Flive_web_images%2Fusedcarsimg%2Fmfc%2F79%2F611265%2Fcover_image-20240610183105.jpeg&w=3840&q=75', 'https://www.carandbike.com/_next/image?url=https%3A%2F%2Fmedia.mahindrafirstchoice.com%2Flive_web_images%2Fusedcarsimg%2Fmfc%2F4464%2F612396%2Fcover_image-20240628162547.jpeg&w=3840&q=75', 'https://www.carandbike.com/_next/image?url=https%3A%2F%2Fmedia.mahindrafirstchoice.com%2Flive_web_images%2Fusedcarsimg%2Fmfc%2F79%2F611322%2Fcover_image-20240608140526.jpeg&w=3840&q=75', 'https://www.carandbike.com/_next/image?url=https%3A%2F%2Fmedia.mahindrafirstchoice.com%2Flive_web_images%2Fusedcarsimg%2Fmfc%2F79%2F611622%2Fcover_image-20240616184222.jpeg&w=3840&q=75', 'https://www.carandbike.com/_next/image?url=https%3A%2F%2Fmedia.mahindrafirstchoice.com%2Flive_web_images%2Fusedcarsimg%2Fmfc%2F79%2F611258%2Fcover_image-20240606181958.jpeg&w=3840&q=75', 'https://www.carandbike.com/_next/image?url=https%3A%2F
# ...

# %%
carSpecifications = soup.find_all(class_="ucInfo flex pt10 pb10")
carSpecs=[]
for i in carSpecifications:
    getSpecs = i.find_all(class_="ucInfoItem relative")
    specs=''
    for j in range(len(getSpecs)):
        if(j==0):
            specs=getSpecs[j].get_text()
        else:
            specs = specs + " | " + getSpecs[j].get_text()
    carSpecs.append(specs)
print(carSpecs)
# Out:
# ['29,960 km | Petrol | Automatic', '22,833 km | Petrol | Automatic', '27,021 km | Petrol | Automatic', '22,485 km | Petrol | Automatic', '22,319 km | Petrol | Automatic', '24,541 km | Petrol | Automatic', '30,033 km | Petrol | Automatic', '32,235 km | Petrol | Automatic', '28,971 km | Petrol | Automatic', '28,299 km | Petrol | Automatic', '24,772 km | Petrol | Automatic', '12,849 km | Petrol | Automatic', '60,236 km | Petrol | Automatic', '38,217 km | Petrol | Automatic', '98,000 km | Diesel | Automatic', '71,518 km | Diesel | Automatic', '28,278 km | Petrol | Automatic', '26,957 km | Petrol | Automatic', '53,740 km | Petrol | Automatic', '17,127 km | Petrol | Automatic', '55,107 km | Petrol | Automatic', '61,411 km | Diesel | Automatic', '40,897 km | Diesel | Automatic', '49,029 km | Petrol | Automatic', '48,090 km | Petrol | Automatic', '32,361 km | Petrol | Automatic', '33,626 km | Petrol | Automatic', '43,620 km | Petrol | Automatic', '40,108 km | Petrol | Automatic', '44,355 km 
# ...

# %%
carEMIDetails = soup.find_all(class_="emi flex gridAc pointer")
carMonthlyEMI=[]
for i in carEMIDetails:
    try:
        i.span.unwrap()
    except:
        pass
    carMonthlyEMI.append(i.get_text().split("/")[0])
print(carMonthlyEMI)
# Out:
# ['₹ 19,597', '₹ 15,118', '₹ 15,118', '₹ 22,285', '₹ 25,059', '₹ 35,424', '₹ 25,644', '₹ 24,425', '₹ 9,519', '₹ 14,670', '₹ 15,118', '₹ 19,597', '₹ 21,613', '₹ 10,862', '₹ 14,222', '₹ 16,909', '₹ 18,477', '₹ 19,597', '₹ 19,771', '₹ 26,316', '₹ 12,878', '₹ 14,222', '₹ 14,446', '₹ 15,678', '₹ 17,805', '₹ 23,404', '₹ 25,420']

# %%
carHealthScore = soup.find_all("div",class_=re.compile("subDiv flex gridAc gridJc "))
carHealthRating = []
carHealthStatus = []
carHealthScore
for i in carHealthScore:
    carHealthRating.append(i.get_text())
    try:
        carHealthStatus.append(i.get("class")[4])
    except:
        carHealthStatus.append("NA")
print(carHealthRating)
print(carHealthStatus)
# Out:
# ['8.0', '7.9', '8.1', '8.6', '8.5', '8.5', '7.6', '8.5', '7.2', '7.8', '8.0', '8.1', '7.8', '7.4', '7.0', '7.0', '7.5', '8.0', '7.5', '8.5', '7.6', '7.4', '6.2', '7.8', '7.2', '8.5', '7.8', '7.5', '7.6', '7.8']
# ['good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'warning', 'good', 'good', 'good', 'good', 'good', 'good', 'good']

# %%
carLoc = soup.find_all(class_="ucFootText truncate truncate1")
carLocation=[]
for i in carLoc:
    carLocation.append(i.get_text())
print(carLocation)
# Out:
# ['Mahindra First Choice, Thane, Mumbai ', 'Mahindra First Choice, Kharghar ', 'Mahindra First Choice, Thane, Mumbai ', 'Mahindra First Choice, Thane, Mumbai ', 'Mahindra First Choice, Thane, Mumbai ', 'Mahindra First Choice, Thane, Mumbai ', 'Mahindra First Choice, Thane, Mumbai ', 'Mahindra First Choice, Thane, Mumbai ', 'Mahindra First Choice, Thane, Mumbai ', 'Mahindra First Choice, Thane, Mumbai ', 'Mahindra First Choice, Thane, Mumbai ', 'Mahindra First Choice, Thane, Mumbai ', 'Mahindra First Choice, Thane, Mumbai ', 'Mahindra First Choice, Thane, Mumbai ', 'Mahindra First Choice, Sanpada, Mumbai ', 'Mahindra First Choice, Kharghar ', 'Mahindra First Choice, Thane, Mumbai ', 'Mahindra First Choice, Thane, Mumbai ', 'Mahindra First Choice, Thane, Mumbai ', 'Mahindra First Choice, Thane, Mumbai ', 'Mahindra First Choice, Thane, Mumbai ', 'Mahindra First Choice, Thane, Mumbai ', 'Mahindra First Choice, Thane, Mumbai ', 'Mahindra First Choice, Kharghar ', 'Mahindra First Choice, Th
# ...

# %%
df = pd.DataFrame.from_dict({"Car Model":carModel, "Year Of Registration": carMakeYear, "Car Specifications": carSpecs, "Location": carLocation, "Condition Rating": carHealthRating, "Condition Status": carHealthStatus, "Asking Price": askingPrice, "Monthly EMI": carMonthlyEMI, "Car Image": carImages}, orient='index')
df = df.transpose()
df
# Out:
#                  Car Model Year Of Registration  \
# 0               Honda City                 2019
# 1               Honda Jazz                 2018
# 2     Maruti Suzuki Baleno                 2018
# 3    Maruti Suzuki S-Cross                 2021
# 4        Maruti Suzuki XL6                 2021
# 5                MG Hector                 2021
# 6             Jeep Compass                 2017
# 7        Maruti Suzuki XL6                 2021
# 8            Hyundai Xcent                 2014
# 9               Honda Jazz                 2018
# 10              Honda Jazz                 2018
# 11      Maruti Suzuki Ciaz                 2018
# 12           Honda City ZX                 2018
# 13              Honda Brio                 2016
# 14                  BMW X1                 2016
# 15  Mercedes-Benz GL-Class                 2015
# 16        Volkswagen Vento                 2016
# 17      Maruti Suzuki Ciaz                 2018
# ...

# %%
df.to_csv("UsedCars.csv",index=False)

# %%
pd.read_csv("UsedCars.csv")
# Out:
#                  Car Model  Year Of Registration  \
# 0               Honda City                  2019
# 1               Honda Jazz                  2018
# 2     Maruti Suzuki Baleno                  2018
# 3    Maruti Suzuki S-Cross                  2021
# 4        Maruti Suzuki XL6                  2021
# 5                MG Hector                  2021
# 6             Jeep Compass                  2017
# 7        Maruti Suzuki XL6                  2021
# 8            Hyundai Xcent                  2014
# 9               Honda Jazz                  2018
# 10              Honda Jazz                  2018
# 11      Maruti Suzuki Ciaz                  2018
# 12           Honda City ZX                  2018
# 13              Honda Brio                  2016
# 14                  BMW X1                  2016
# 15  Mercedes-Benz GL-Class                  2015
# 16        Volkswagen Vento                  2016
# 17      Maruti Suzuki Ciaz                  2018
# ...
